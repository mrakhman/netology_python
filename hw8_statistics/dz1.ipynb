# %% [markdown]
# # Домашнее задание по статистическому анализу на python

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as sts
# %matplotlib inline

# %% [markdown]
# ### Построить нормальное гауссово распределение для двух переменных: x, y. Нарисовать их на плоскости (scatter plot).

# %%
mu1 = 20
sigma1 = 5

mu2 = 10
sigma2 = 10
 
# зададим нормально распределенную случайную величину
norm_rv1 = sts.norm(loc=mu1, scale=sigma1)
norm_rv2 = sts.norm(loc=mu2, scale=sigma2)

# сгенерируем 1000 значений
x = norm_rv1.rvs(size=1000)
y = norm_rv2.rvs(size=1000)

# %%
plt.scatter(x, y, marker='.')
plt.grid()
plt.xlabel('выборка X', fontsize=16)
plt.ylabel('выборка Y', fontsize=16)
# plt.show()
# Out:
# Text(0,0.5,'выборка Y')

# %% [markdown]
# ### Нарисовать плотность распределения полученной выборки x.

# %%
plt.hist(x, 50)
plt.show()

# %% [markdown]
# ### Изменить гауссово распределение с помощью матрицы масштабирования Scale = [[n, 0], [0, n]], где n - число, во сколько раз увеличиваем разброс данной выборки. Построить график зависимости (корелляции) x от y.

# %%
X = np.vstack((x, y)).T
X
# Out:
# array([[ 14.75212779,   5.66619636],
#        [ 19.47850551,  16.88215074],
#        [ 20.83123   ,  13.54940578],
#        ...,
#        [ 16.16304559,   1.92598578],
#        [ 15.52015904,  11.27878313],
#        [ 23.89372978,   5.24467452]])

# %%
# Матрица масштабирования
sx, sy = 0.7, 3.4
Scale = np.array([[sx, 0], [0, sy]])

# %%
# Умножаем исходную матрицу на матрицу масштабирования
Y = X.dot(Scale)
Y
# Out:
# array([[ 10.32648945,  19.26506762],
#        [ 13.63495385,  57.39931252],
#        [ 14.581861  ,  46.06797966],
#        ...,
#        [ 11.31413191,   6.54835167],
#        [ 10.86411133,  38.34786264],
#        [ 16.72561085,  17.83189337]])

# %%
plt.scatter(Y[:,0], Y[:,1], marker='.')

# %% [markdown]
# ### Нарисовать плотность распределения полученной выборки x. Сравнить с предыдущим графиком x.

# %%
plt.hist(X[:,0], 50)

plt.hist(Y[:,0], 50)

plt.legend(['Old X', 'New X'])

plt.show()

# %% [markdown]
# По сравнению с распределением до умножения на матрицу масштабирования разброс значений по оси X уменьшился, график стал уже, медиана и весь график сместились к точке (0;0)

# %% [markdown]
# ### Посчитать коэффициент Пирсона для переменных x, y. Что означает положительное значение коэффициента? Отрицательное? 0?

# %% [markdown]
# ### Сгенерировать равномерное распределение на отрезке [1, 10]. Нарисовать график плотности распределения. Чем оно отличается от нормального?

# %% [markdown]
# Найти на графике примеры выброса. Что они означают?

# %% [markdown]
# Выбросами можно считать

# %% [markdown]
# Найти корелляцию в следующих данных:

# %%
import io
import requests
url="http://yustiks.ru/avocado.csv"
df=pd.read_csv(url)
df[:3]
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany

# %% [markdown]
# Корелляция между: 4046 - Total number of avocados with PLU 4046 sold  и например Average Price. Если корелляция есть, то скорее всего, данный вид авокадо дорогой по цене и он влияет на среднюю стоимость.
